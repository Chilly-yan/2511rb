# %%
import talib
import numpy as np

# %%
data = np.random.random(100)

# %%
tradeinfo = {'tradeDate': range(100),
             'price': data}

# %%
talib.EMA(tradeinfo['price'], timeperiod=3)
# Out:
# array([       nan,        nan, 0.5351955 , 0.74326011, 0.73118495,
#        0.70250181, 0.55418209, 0.46774737, 0.26641332, 0.39137744,
#        0.59583859, 0.58892138, 0.69475723, 0.74743755, 0.83944426,
#        0.50795332, 0.75353769, 0.83368647, 0.78372487, 0.74015228,
#        0.6881731 , 0.81848528, 0.51840053, 0.40802657, 0.59510431,
#        0.76067208, 0.84964844, 0.63257903, 0.71996271, 0.81567273,
#        0.60748041, 0.41077558, 0.66469007, 0.63171665, 0.64964061,
#        0.54186161, 0.60345945, 0.32025829, 0.20584747, 0.17560262,
#        0.16358156, 0.43642197, 0.3664432 , 0.29468517, 0.33817966,
#        0.32231889, 0.19829989, 0.24330354, 0.51008011, 0.54342137,
#        0.44581702, 0.45022969, 0.58759714, 0.70652441, 0.37659174,
#        0.57930111, 0.52042346, 0.55792397, 0.5031667 , 0.63069016,
#        0.67032692, 0.41589396, 0.59385139, 0.29781025, 0.38975008,
#        0.46843266, 0.39421026, 0.33187681, 0.47133955, 0.28302849,
# ...
